# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# from langchain_google_genai import GoogleGenerativeAI

# llm = GoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
# res = llm.invoke("current president of Russia")

# print(res.text)

# %% [markdown]
# #### static prompts

# %%
prompts = [
    ("system", "you are a javascript developer"),
    ("user", "how to print logs in my code")
]

res = llm.invoke(prompts)

print(res.text)
# Out:
# In JavaScript, the way you print logs depends on where your code is running (Browser vs. Node.js). In both environments, the standard approach is using the `console` object.
#
# Here is a breakdown of how to use it effectively:
#
# ### 1. The Basics
# The most common method is `console.log()`.
#
# ```javascript
# console.log("Hello, world!");
#
# const user = { name: "Alice", age: 25 };
# console.log("User data:", user);
# ```
#
# ---
#
# ### 2. Different Log Levels (Best for Debugging)
# Using different levels helps you filter logs in your browser's console or your terminal.
#
# *   **`console.info()`**: Used for general informational messages.
# *   **`console.warn()`**: Used for potential issues (displays as yellow in most consoles).
# *   **`console.error()`**: Used for errors (displays as red and often includes a stack trace).
# *   **`console.debug()`**: Used for verbose information that you usually want hidden in production.
#
# ```javascript
# console.info("Process started");
# console.warn("API response is slow");
# console.error("Failed to fetch data");
# ```
#
# ---
#
# ### 3. Pro Tips for Better Logs
#
# #### A. Use Template Literals (String Interpolation)
# Use backticks (`` ` ``) and `${}` to embed variables directly into strings.
# ```javascript
# const id = 101;
# console.log(`The ID is: ${id}`);
# ```
#
# #### B. The "Object Table" View
# If you have an array of objects, `console.table()` is incredibly useful for readability.
# ```javascript
# const users = [
#   { name: "Alice", id: 1 },
#   { name: "Bob", id: 2 }
# ];
# console.table(users);
# ```
#
# #### C. Grouping Logs
# If you have a lot of related logs, group them to keep your console clean.
# ```javascript
# console.group("User Details");
# console.log("Name: Alice");
# console.log("Role: Admin");
# console.groupEnd();
# ```
#
# #### D. Counting and Timing
# *   **`console.count()`**: Tracks how many times a line of code is executed.
# *   **`console.time()` & `console.timeEnd()`**: Measures how long a block of code takes to run.
#
# ```javascript
# console.time("TaskDuration");
# // ... your code here ...
# console.timeEnd("TaskDuration"); // Prints the time in milliseconds
# ```
#
# ---
#
# ### 4. Important: Managing Logs in Production
# While logs are great for development, leaving too many `console.log` statements in your production code can:
# 1.  **Expose sensitive data** to the browser console.
# 2.  **Slow down performance** (excessive logging is expensive).
#
# **Recommendation:**
# *   **Use a Logger Library:** In Node.js projects, don't just use `console.log`. Use professional libraries like **[Winston](https://github.com/winstonjs/winston)** or **[Pino](https://getpino.io/)**. They allow you to log to files, filter by environment, and format logs as JSON (which is better for cloud log collectors).
# *   **Remove logs during build:** If you use tools like Webpack, Vite, or Babel, there are plugins that can automatically strip out all `console.log` statements when you build your production code.
#
# **Do you have a specific project setup (like React, Node.js, or vanilla JS)? I can give you more targeted advice!**
