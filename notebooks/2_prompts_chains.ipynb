# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI
# llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
# prompts = [
#     {"role": "system", "content": "you are a javascript developer, who gives answers in a max 50 words"},
#     {"role": "user", "content": "difference between var, let and const in javascript"}
# ]

# %%
# res = llm.invoke(prompts)
# print(res.text)

# %% [markdown]
# #### Dynamic Prompts

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")
out = StrOutputParser()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role": "system", "content": "you are a translator and translate message in {language} language"},
    {"role": "user", "content": "{user_query}"}
])

# %%
# final_prompt = prompts.format_prompt(language="hindi", user_query="hello, how are you?")
# final_prompt

# %%
# final_prompt2 = prompts.format_messages(language="hindi", user_query="hello, how are you?")
# final_prompt2

# %%
# prompts.invoke({"language": "hindi", "user_query": "hello, how are you?"})

# %%
# res = llm.invoke(final_prompt)
# res

# %% [markdown]
# #### chain - prompts.invoke() inside llm.invoke() | language and user_query parameters are tranfered inside
# ##### prompts and llm can be invoked hence called **runnables**, prompts.invoke  -- result tranfered --> llm.invoke

# %%
# res = llm.invoke(prompts.invoke({"language": "french", "user_query": "hello, how are you?"}))
# res

# %%
# print(res.content)

# %%
# print(res.content[0]['text'])

# %%
# my custom function to convert text to uppercase
def toUppercase(text: str) -> str: 
    return text.upper()

# %% [markdown]
# ### chains in langchain - core concept

# %%
chains = prompts | llm | out | toUppercase

# %%
chains
# Out:
# ChatPromptTemplate(input_variables=['language', 'user_query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='you are a translator and translate message in {language} language'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['user_query'], input_types={}, partial_variables={}, template='{user_query}'), additional_kwargs={})])
# | ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.2', 'langchain-google-genai': '4.4.0'}}, profile={}, google_api_key=SecretStr('**********'), model='gemini-3.1-flash', temperature=None, client=<google.genai.client.Client object at 0x000001ED8986B5C0>, default_metadata=(), model_kwargs={})
# | StrOutputParser()
# | RunnableLambda(toUppercase)

# %%
res = chains.invoke({"language": "italian", "user_query": "hello, how are you?"})
res
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_google_genai\chat_models.py:4177, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    4176 try:
# -> 4177     response: GenerateContentResponse = self.client.models.generate_content(
#    4178         **request,
#    4179     )
#    4180 except ClientError as e:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\google\genai\models.py:6270, in Models.generate_content(self, model, contents, config)
#    6269 i += 1
# -> 6270 response = self._generate_content(
#    6271     model=model, contents=contents, config=parsed_config_to_call
#    6272 )
#    6274 if not function_map:
#
# ...
